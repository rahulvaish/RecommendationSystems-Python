# %%
import pandas as pd
import numpy as np

data= pd.read_csv('C:/Users/Lenovo/Desktop/IPY/MoviesDataSet/movies_metadata.csv', low_memory=False)
data.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#      ...     release_date      revenue runtime  \
# 0    ...       1995-10-30  373554033.0    81.0
# 1    ...       1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %%
#As we can see that there are few columns that are missing from the 'view'.
#To discover all-
data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#Re-Checking NULL values and sorting them !
Isnull=data.isnull().sum()
Isnull.sort_values(inplace=True, ascending=False)
print(Isnull)
# Out:
# belongs_to_collection    40972
# homepage                 37684
# tagline                  25054
# overview                   954
# poster_path                386
# runtime                    263
# status                      87
# release_date                87
# imdb_id                     17
# original_language           11
# vote_average                 6
# vote_count                   6
# revenue                      6
# spoken_languages             6
# title                        6
# video                        6
# popularity                   5
# production_companies         3
# production_countries         3
# original_title               0
# id                           0
# genres                       0
# budget                       0
# adult                        0
# dtype: int64

# %%
#runtime                    263
#release_date                87
#vote_average                 6
#vote_count                   6
#Let's see revenue            6
#popularity                   5
#IMDB CALCULATION

# %%
data = data[data['adult'] == 'False']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')
data['year'] = data['release_date'].dt.year

# %%
data['year'].fillna(0, inplace=True)

# %%
data['year'] = data['year'].astype('int')

# %%
#data['year']

# %%
print(min(data['year']))
print(max(data['year']))
print(data['year'].mean())
# Out:
# 0
# 2020
# 1988.111101333216

# %%
data = data[data['year'] > 2000]

# %%
#Calculate the number of votes garnered by the 80th percentile movie
m = data['vote_count'].quantile(0.90)
print(m)
# Out:
# 269.0

# %%
data = data[data['vote_count'] >= m]

# %%
data = data[data['runtime'] > (data['runtime'].median())]

# %%
data.shape
# Out:
# (1161, 25)

# %%
data = data[data['vote_average'] > (data['vote_average'].quantile(0.80))]

# %%
list_movies = data.sort_values(['vote_average'], ascending=[False])

# %%
list_movies['title']
# Out:
# 40251                                           Your Name.
# 12481                                      The Dark Knight
# 5481                                         Spirited Away
# 25465                                                Mommy
# 18465                                     The Intouchables
# 5878                                           City of God
# 43190                                     Band of Brothers
# 9698                                  Howl's Moving Castle
# 22879                                         Interstellar
# 5857                                           The Pianist
# 32144                                                 Room
# 42015                                  The Invisible Guest
# 7000         The Lord of the Rings: The Return of the King
# 16881                                                Senna
# 38718                                       The Handmaiden
# 15480                                            Inception
# 9430                                                Oldboy
# 37863                                          Sing Street
# 24860                                   The Imitation Game
# 11354                                         The Prestige
# 24209                      The Tale of the Princess Kaguya
# 20779                                        Wolf Children
# 5814                 The Lord of the Rings: The Two Towers
# 4863     The Lord of the Rings: The Fellowship of the Ring
# 41128                                                 Lion
# 23399                                     The Normal Heart
# 15530                                           Mr. Nobody
# 27656                                          The Pacific
# 40882                                           La La Land
# 22131                              The Wolf of Wall Street
#                                ...
# 11353                                      Children of Men
# 11349                            The Last King of Scotland
# 10881                                  Lucky Number Slevin
# 10688                          Sympathy for Lady Vengeance
# 10240                                             Serenity
# 8234                                       The Incredibles
# 7170                                      Good bye, Lenin!
# 5678               Harry Potter and the Chamber of Secrets
# 4849                                  The Royal Tenenbaums
# 4751                              The Man Who Wasn't There
# 12165                                    American Gangster
# 12588                                             Iron Man
# 24366                                                 Fury
# 13013                                 Synecdoche, New York
# 24241                                      American Sniper
# 23561                                              Birdman
# 22206                                        Lone Survivor
# 22058                      The Hunger Games: Catching Fire
# 22043                                       The Book Thief
# 21694                                             Nebraska
# 21276                                        The Conjuring
# 20922                              Star Trek Into Darkness
# 18952                             Three Steps Above Heaven
# 17973                          We Need to Talk About Kevin
# 17818                                         The Avengers
# 4180                                         Moulin Rouge!
# 13893               Harry Potter and the Half-Blood Prince
# 13643                                            Star Trek
# 13507                      The Girl with the Dragon Tattoo
# 17677                                   The Skin I Live In
# Name: title, Length: 191, dtype: object
